# %%
import pandas as pd
import os

# %%
os.getcwd()
df = pd.read_csv('Spotify/Features.csv')
df.head()
# Out:
#                        id               name  duration  energy  key  loudness  \
# 0  0VjIjW4GlUZAMYd2vXMi3b    Blinding Lights      3.33   0.730    1    -5.934
# 1  7qiZfU4dY1lWllzX7mPBI3       Shape of You      3.90   0.652    1    -3.183
# 2  2XU0oxnq2qxCpomAAuJY8K       Dance Monkey      3.49   0.588    6    -6.400
# 3  7qEHsqek33rTcFNT9PFqLf  Someone You Loved      3.04   0.405    1    -5.679
# 4  0e7ipj03S05BNilyu5bRzt           Rockstar      3.64   0.520    5    -6.136
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0598       0.00146          0.000095    0.0897    0.334
# 1     0       0.0802       0.58100          0.000000    0.0931    0.931
# 2     0       0.0924       0.69200          0.000104    0.1490    0.513
# 3     1       0.0319       0.75100          0.000000    0.1050    0.446
# 4     0       0.0712       0.12400          0.000070    0.1310    0.129
#
#      tempo  danceability
# 0  171.005         0.514
# ...

# %%
df.sort_values('danceability',ascending=False).head(5)
# Out:
#                         id            name  duration  energy  key  loudness  \
# 82  0JP9xo3adEtGSdUEISiszL       Moonlight      2.25   0.537    9    -5.723
# 45  7KXjTSCq5nL1LoYtL7XAwS          Humble      2.95   0.621    1    -6.638
# 62  7lQ8MOhq6IN2w8EYcFNSUk      Without Me      4.84   0.669    7    -2.827
# 86  0nbXyq5TXYPCO7pr3N8S4I         The Box      3.28   0.586   10    -6.687
# 36  7m9OqQk4RVRkw9JJdeAw96  Jocelyn Flores      1.99   0.391    0    -9.144
#
#     mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 82     0       0.0804      0.556000          0.004040    0.1020    0.711
# 45     0       0.1020      0.000282          0.000054    0.0958    0.421
# 62     1       0.0738      0.002860          0.000000    0.2370    0.662
# 86     0       0.0559      0.104000          0.000000    0.7900    0.642
# 36     0       0.2420      0.469000          0.000004    0.2970    0.437
#
#       tempo  danceability
# 82  128.009         0.921
# ...

# %%
df['dancelives'] = df['danceability'] + df['liveness']

# %%
df.sort_values('dancelives',ascending=False).head(5)
# Out:
#                         id            name  duration  energy  key  loudness  \
# 86  0nbXyq5TXYPCO7pr3N8S4I         The Box      3.28   0.586   10    -6.687
# 21  6DCZcSspjsKoFjzjrWoCdn      God's Plan      3.32   0.449    7    -9.211
# 55  1Lim1Py7xBgbAkAys3AGAG         Lean On      2.94   0.809    7    -3.081
# 36  7m9OqQk4RVRkw9JJdeAw96  Jocelyn Flores      1.99   0.391    0    -9.144
# 95  5kqIPrATaCc2LqxVWzQGbk         7 Years      3.96   0.473   10    -5.829
#
#     mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 86     0       0.0559       0.10400          0.000000     0.790    0.642
# 21     1       0.1090       0.03320          0.000083     0.552    0.357
# 55     0       0.0625       0.00346          0.001230     0.565    0.274
# 36     0       0.2420       0.46900          0.000004     0.297    0.437
# 95     1       0.0514       0.28700          0.000000     0.391    0.340
#
#       tempo  danceability  dancelives
# ...

# %%
streams = pd.read_csv('Spotify/Streams.csv')

# %%
streams.head()
# Out:
#                 Song                           Artist  Streams (Billions)  \
# 0    Blinding Lights                       The Weeknd               3.449
# 1       Shape of You                       Ed Sheeran               3.398
# 2       Dance Monkey                      Tones And I               2.770
# 3  Someone You Loved                    Lewis Capaldi               2.680
# 4           Rockstar  Post Malone featuring 21 Savage               2.620
#
#   Release Date
# 0    29-Nov-19
# 1    06-Jan-17
# 2    10-May-19
# 3    08-Nov-18
# 4    15-Sep-17

# %%
df1 = streams.merge(df, left_on='Song', right_on='name')

# %%
df1.sort_values('danceability',ascending=False).head(5)
# Out:
#               Song          Artist  Streams (Billions) Release Date  \
# 82       Moonlight    XXXTentacion               1.600    16-Mar-18
# 45          Humble  Kendrick Lamar               1.812    30-Mar-17
# 62      Without Me          Halsey               1.692    04-Oct-18
# 86         The Box     Roddy Ricch               1.586    06-Dec-19
# 36  Jocelyn Flores    XXXTentacion               1.905    31-Oct-17
#
#                         id            name  duration  energy  key  loudness  \
# 82  0JP9xo3adEtGSdUEISiszL       Moonlight      2.25   0.537    9    -5.723
# 45  7KXjTSCq5nL1LoYtL7XAwS          Humble      2.95   0.621    1    -6.638
# 62  7lQ8MOhq6IN2w8EYcFNSUk      Without Me      4.84   0.669    7    -2.827
# 86  0nbXyq5TXYPCO7pr3N8S4I         The Box      3.28   0.586   10    -6.687
# 36  7m9OqQk4RVRkw9JJdeAw96  Jocelyn Flores      1.99   0.391    0    -9.144
#
#     mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %%
df1.corrwith(df1['energy']).sort_values()
# Out:
# /tmp/ipykernel_3243/2908550424.py:1: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corrwith(df1['energy']).sort_values()
# acousticness         -0.703552
# instrumentalness     -0.275034
# Streams (Billions)   -0.266803
# key                  -0.087542
# speechiness          -0.059644
# liveness             -0.033251
# dancelives           -0.010469
# duration              0.008279
# danceability          0.014443
# mode                  0.095255
# valence               0.238659
# tempo                 0.259863
# loudness              0.741794
# energy                1.000000
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.scatterplot(data=df1, x='speechiness', y='danceability')
# Out:
# <AxesSubplot: xlabel='speechiness', ylabel='danceability'>

# %%
streams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Song                100 non-null    object
#  1   Artist              100 non-null    object
#  2   Streams (Billions)  100 non-null    float64
#  3   Release Date        100 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 3.2+ KB

# %%
sns.heatmap(df1.corr())
# Out:
# /tmp/ipykernel_3243/781785195.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df1.corr())
# <AxesSubplot: >
